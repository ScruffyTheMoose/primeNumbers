# %%
import sys
sys.path.append('..')

import progressions as prog
import pandas as pd

# %%
primes = pd.read_csv('../primes_100.csv')

primeList = primes['primes'].tolist()

primes.head(10)
# Out:
#    primes
# 0       2
# 1       3
# 2       5
# 3       7
# 4      11
# 5      13
# 6      17
# 7      19
# 8      23
# 9      29

# %%
result_dict = dict()

for k in range(2, 212, 2):
    res = prog.llap(primeList, k)
    result_dict[k] = res
    
# prev best 8m 22.2s

# %%
df = pd.DataFrame(result_dict).head(20)
df.head(20)
# Out:
#            2       4     6       8       10    12      14      16    18   \
# length       2       2     4       2       2     4       2       2     4
# step         2       4     6       8      10    12      14      16    18
# total   440310  440257  9329  439906  586810  9454  528093  441054  9412
#
#            20   ...   192     194     196    198     200     202    204  \
# length       2  ...     4       2       2      4       2       2      4
# step        20  ...   192     194     196    198     200     202    204
# total   586266  ...  9409  444890  529086  13341  587376  444963  11614
#
#            206     208  210
# length       2       2   10
# step       206     208  210
# total   444239  480309    1
#
# [3 rows x 105 columns]

# %%
df.to_csv(path_or_buf='../progressionsBeta.csv')
